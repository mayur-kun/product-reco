# %% [markdown]
# ## DATA IMPORT & BASIC EDA

# %%
import pandas as pd
import numpy as np

import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import spacy

from sklearn.feature_extraction.text import TfidfVectorizer

from sklearn.metrics.pairwise import linear_kernel
from sklearn.metrics.pairwise import cosine_similarity
from scipy.sparse import hstack
from sklearn.preprocessing import MaxAbsScaler

# %%
df = pd.read_csv("product_reviews_dataset.csv")

# %%
df.shape
# Out:
# (34660, 9)

# %%
df.head(10)
# Out:
#                                              product  source
# 0  electronics brand product name Tablet A 10.1 T...  Target  \
# 1  electronics brand product name Tablet A 10.1 T...  Target
# 2  electronics brand product name Tablet A 10.1 T...  Target
# 3  electronics brand product name Tablet A 10.1 T...  Target
# 4  electronics brand product name Tablet A 10.1 T...  Target
# 5  electronics brand product name Tablet A 10.1 T...  Target
# 6  electronics brand product name Tablet A 10.1 T...  Target
# 7  electronics brand product name Tablet A 10.1 T...  Target
# 8  electronics brand product name Tablet A 10.1 T...  Target
# 9  electronics brand product name Tablet A 10.1 T...  Target
#
#                                           categories
# 0  Electronics,iPad & Tablets,All Tablets,XYZ bra...  \
# 1  Electronics,iPad & Tablets,All Tablets,XYZ bra...
# 2  Electronics,iPad & Tablets,All Tablets,XYZ bra...
# 3  Electronics,iPad & Tablets,All Tablets,XYZ bra...
# 4  Electronics,iPad & Tablets,All Tablets,XYZ bra...
# 5  Electronics,iPad & Tablets,All Tablets,XYZ bra...
# 6  Electronics,iPad & Tablets,All Tablets,XYZ bra...
# 7  Electronics,iPad & Tablets,All Tablets,XYZ bra...
# 8  Electronics,iPad & Tablets,All Tablets,XYZ bra...
# 9  Electronics,iPad & Tablets,All Tablets,XYZ bra...
#
#                        date didPurchase doRecommend  rating
# 0  2021-01-13T00:00:00.000Z         NaN        True     5.0  \
# 1  2021-01-13T00:00:00.000Z         NaN        True     5.0
# 2  2021-01-13T00:00:00.000Z         NaN        True     5.0
# 3  2021-01-13T00:00:00.000Z         NaN        True     4.0
# 4  2021-01-12T00:00:00.000Z         NaN        True     5.0
# 5  2021-01-12T00:00:00.000Z         NaN        True     5.0
# 6  2021-01-12T00:00:00.000Z         NaN        True     4.0
# 7  2021-01-12T00:00:00.000Z         NaN        True     5.0
# 8  2021-01-23T00:00:00.000Z         NaN        True     5.0
# 9  2021-01-23T00:00:00.000Z         NaN        True     5.0
#
#                                              reviews
# 0  This product so far has not disappointed. My c...  \
# 1  great for beginner or experienced person. Boug...
# 2  Inexpensive tablet for him to use and learn on...
# 3  I've had my XYZ brand HD 8 two weeks now and I...
# 4  I bought this for my grand daughter when she c...
# 5  This Target XYZ brand 8 inch tablet is the per...
# 6  Great for e-reading on the go, nice and light ...
# 7  I gave this as a Christmas gift to my inlaws, ...
# 8  Great as a device to read books. I like that i...
# 9  I love ordering books and reading them with th...
#
#                                      title
# 0                               brand name
# 1                                very fast
# 2  Beginner tablet for our 9 year old son.
# 3                                  Good!!!
# 4                Fantastic Tablet for kids
# 5                    Just what we expected
# 6                    great e-reader tablet
# 7                          Great for gifts
# 8                        Great for reading
# 9             Great and lightweight reader

# %%
df.tail(10)
# Out:
#       product  source                                         categories
# 34650     NaN  Target  Computers/Tablets & Networking,Tablet & eBook ...  \
# 34651     NaN  Target  Computers/Tablets & Networking,Tablet & eBook ...
# 34652     NaN  Target  Computers/Tablets & Networking,Tablet & eBook ...
# 34653     NaN  Target  Computers/Tablets & Networking,Tablet & eBook ...
# 34654     NaN  Target  Computers/Tablets & Networking,Tablet & eBook ...
# 34655     NaN  Target  Computers/Tablets & Networking,Tablet & eBook ...
# 34656     NaN  Target  Computers/Tablets & Networking,Tablet & eBook ...
# 34657     NaN  Target  Computers/Tablets & Networking,Tablet & eBook ...
# 34658     NaN  Target  Computers/Tablets & Networking,Tablet & eBook ...
# 34659     NaN  Target  Computers/Tablets & Networking,Tablet & eBook ...
#
#                            date didPurchase doRecommend  rating
# 34650  2016-03-07T00:00:00.000Z         NaN         NaN     2.0  \
# 34651  2021-07-12T00:00:00.000Z         NaN         NaN     5.0
# 34652      2012-11-13T00:00:00Z         NaN         NaN     1.0
# 34653      2012-11-02T00:00:00Z         NaN         NaN     1.0
# 34654      2012-10-16T00:00:00Z         NaN         NaN     1.0
# 34655      2012-09-18T00:00:00Z         NaN         NaN     3.0
# 34656      2012-11-21T00:00:00Z         NaN         NaN     1.0
# 34657      2012-10-19T00:00:00Z         NaN         NaN     1.0
# 34658      2012-10-31T00:00:00Z         NaN         NaN     1.0
# 34659      2012-12-23T00:00:00Z         NaN         NaN     1.0
#
#                                                  reviews
# 34650  Although the description states that this will...  \
# 34651                                   Connects snugly!
# 34652  So I was already not too pleased with Target's...
# 34653  As a charger, it works but is nothing special....
# 34654  This is exactly like any other usb power charg...
# 34655  This is not appreciably faster than any other ...
# 34656  Target should include this charger with the br...
# 34657  Love my brand name XYZ brand but I am really d...
# 34658  I was surprised to find it did not come with a...
# 34659  to spite the fact that i have nothing but good...
#
#                                                    title
# 34650                                      Disappointed!
# 34651                                       Nice contact
# 34652                                         Ridiculous
# 34653                                    Not As Expected
# 34654                                      Not Necessary
# 34655  Not appreciably faster than any other 1.8A cha...
# 34656                                 Should be included
# 34657                              Disappointing Charger
# 34658                                Not worth the money
# 34659                              as with everyone else

# %%
df.dtypes
# Out:
# product         object
# source          object
# categories      object
# date            object
# didPurchase     object
# doRecommend     object
# rating         float64
# reviews         object
# title           object
# dtype: object

# %%
# Checking number of unique values present in each column.

column_names = df.columns
unique_values = df.nunique()

print("\nNumber of Unique Values in each Column:")
for col, count in unique_values.items():
    print(f"{col}: {count}")
# Out:
# Number of Unique Values in each Column:
# product: 60
# source: 6
# categories: 44
# date: 1078
# didPurchase: 1
# doRecommend: 2
# rating: 5
# reviews: 34659
# title: 19686

# %%
# Checking unique value labels and their occurences for columns with least number of unique values

cols = ["source", "didPurchase", "doRecommend", "rating"]

for col in cols:
    print("\n------- {0} -------\n".format(col))
    print(df[col].value_counts())
# Out:
# ------- source -------
#
# source
# Target                          28701
# Target XYZ brand Tv              5056
# Target Echo                       636
# Target XYZ brand                  256
# Target Digital Services Inc.       10
# Target Coco T                       1
# Name: count, dtype: int64
#
# ------- didPurchase -------
#
# didPurchase
# True    1
# Name: count, dtype: int64
#
# ------- doRecommend -------
#
# doRecommend
# True     32682
# False     1384
# Name: count, dtype: int64
#
# ------- rating -------
#
# rating
# 5.0    23775
# 4.0     8541
# 3.0     1499
# 1.0      410
# 2.0      402
# Name: count, dtype: int64

# %% [markdown]
# __All the labels seem meaningful, although the count in the "didPurchase" column is very low.__

# %% [markdown]
# __'Date' column can be used to see which products were recommended to users, and if they ended up being purchased after recommendation.__

# %% [markdown]
# # Handling missing values.

# %%
df.isnull().sum()
# Out:
# product         6760
# source             0
# categories         0
# date              39
# didPurchase    34659
# doRecommend      594
# rating            33
# reviews            1
# title              6
# dtype: int64

# %% [markdown]
# __As observed before, the "didPurchase" column have more than 99% missing values. Also, there are significant number of missing__
# __values in the "product" column.__

# %%
# Dropping 'didPurchase' column
df = df.drop("didPurchase", axis=1)

# %%
# Dropping rows with NaN values in 'product' column

df = df.dropna(subset=['product'])

# %%
df.isnull().sum()
# Out:
# product          0
# source           0
# categories       0
# date            27
# doRecommend    491
# rating          32
# reviews          1
# title            4
# dtype: int64

# %%
# Impute missing values in 'rating' with median
df['rating'] = df['rating'].fillna(df['rating'].median())

# %%
# Imputing NaN values using mode imputation (most frequent value)

mode_value = df['doRecommend'].mode().iloc[0]
df['doRecommend'] = df['doRecommend'].fillna(mode_value)

# %%
# Dropping rows with NaN values in 'date, 'reviews' and 'title' columns

df = df.dropna(subset=['date', 'reviews', 'title'])

# %%
df.isnull().sum()
# Out:
# product        0
# source         0
# categories     0
# date           0
# doRecommend    0
# rating         0
# reviews        0
# title          0
# dtype: int64

# %% [markdown]
# __Except 'ratings' column, all columns contain textual data. The next step will be to preprocess this data.__

# %% [markdown]
# ## PREPROCESSING TEXTUAL DATA

# %%
# Convert text data to lowercase

text_cols = ['product', 'source', 'categories', 'reviews', 'title']

for col in text_cols:
    df[col] = df[col].apply(lambda x: str(x).lower() if pd.notnull(x) else x)

# %%
df.head()
# Out:
#                                              product  source
# 0  electronics brand product name tablet a 10.1 t...  target  \
# 1  electronics brand product name tablet a 10.1 t...  target
# 2  electronics brand product name tablet a 10.1 t...  target
# 3  electronics brand product name tablet a 10.1 t...  target
# 4  electronics brand product name tablet a 10.1 t...  target
#
#                                           categories
# 0  electronics,ipad & tablets,all tablets,xyz bra...  \
# 1  electronics,ipad & tablets,all tablets,xyz bra...
# 2  electronics,ipad & tablets,all tablets,xyz bra...
# 3  electronics,ipad & tablets,all tablets,xyz bra...
# 4  electronics,ipad & tablets,all tablets,xyz bra...
#
#                        date  doRecommend  rating
# 0  2021-01-13T00:00:00.000Z         True     5.0  \
# 1  2021-01-13T00:00:00.000Z         True     5.0
# 2  2021-01-13T00:00:00.000Z         True     5.0
# 3  2021-01-13T00:00:00.000Z         True     4.0
# 4  2021-01-12T00:00:00.000Z         True     5.0
#
#                                              reviews
# 0  this product so far has not disappointed. my c...  \
# 1  great for beginner or experienced person. boug...
# 2  inexpensive tablet for him to use and learn on...
# 3  i've had my xyz brand hd 8 two weeks now and i...
# 4  i bought this for my grand daughter when she c...
#
#                                      title
# 0                               brand name
# 1                                very fast
# 2  beginner tablet for our 9 year old son.
# 3                                  good!!!
# 4                fantastic tablet for kids

# %% [markdown]
# __There are 55 different products, as shown below.__

# %%
print(df['product'].value_counts())
# Out:
# product
# xyz brand tablet, 7 display, wi-fi, 8 gb - includes special offers, magenta                                                                                                                                                   10966
# retail brand brand name paperwhite - ebook reader - 4 gb - 6 monochrome paperwhite - touchscreen - wi-fi - black,,,                                                                                                            3176
# electronics brand product name tablet a 10.1 tablet, 8 hd display, wi-fi, 16 gb - includes special offers, magenta                                                                                                             2814
# retail brand xyz brand tv,,,\r\nretail brand xyz brand tv,,,                                                                                                                                                                   2525
# electonics brand home\r\nelectonics brand home                                                                                                                                                                                 2100
# xyz brand kids edition tablet, 7 display, wi-fi, 16 gb, green kid-proof case                                                                                                                                                   1683
# \nelectonics brand home                                                                                                                                                                                                        1199
# brand new electronics brand ipad16gb 7 ips display tablet wifi 16 gb blue,,,                                                                                                                                                   1036
# brand name voyage e-reader, 6 high-resolution display (300 ppi) with adaptive built-in light, pagepress sensors, wi-fi - includes special offers,                                                                               580
# xyz brand tablet, 7 display, wi-fi, 8 gb - includes special offers, black                                                                                                                                                       358
# retail brand tap portable bluetooth and wi-fi speaker - black,,,\r\nretail brand tap portable bluetooth and wi-fi speaker - black,,,                                                                                            317
# all-new pocketbook touch hd 3 e-reader - black, 6 glare-free touchscreen display, wi-fi -  includes special offers,,                                                                                                            212
# retail brand 5w usb official oem charger and power adapter for xyz brand tablets and brand name ereaders,,,\r\nretail brand 5w usb official oem charger and power adapter for xyz brand tablets and brand name ereaders,,,      205
# electronics brand product name tablet a 10.1 tablet, 8 hd display, wi-fi, 32 gb - includes special offers, magenta                                                                                                              157
# retail brand xyz brand hd 8 8in tablet 16gb black b018szt3bk 6th gen (2016) android,,,\r\nretail brand xyz brand hd 8 8in tablet 16gb black b018szt3bk 6th gen (2016) android,,,                                                134
# retail brand xyz brand hd 10 tablet, wi-fi, 16 gb, special offers - silver aluminum,,,\r\nretail brand xyz brand hd 10 tablet, wi-fi, 16 gb, special offers - silver aluminum,,,                                                128
# brand name oasis e-reader with leather charging cover - merlot, 6 high-resolution display (300 ppi), wi-fi - includes special offers,,                                                                                           67
# 9w powerfast official oem usb charger and power adapter for xyz brand tablets and brand name ereaders,,,\r\n9w powerfast official oem usb charger and power adapter for xyz brand tablets and brand name ereaders,,,             35
# brand name paperwhite e-reader - white, 6 high-resolution display (300 ppi) with built-in light, wi-fi - includes special offers,,                                                                                               30
# retail brand - brand name voyage - 4gb - wi-fi + 3g - black,,,\r\nretail brand - brand name voyage - 4gb - wi-fi + 3g - black,,,                                                                                                 24
# xyz brand hd 8 tablet with alexa, 8 hd display, 32 gb, tangerine - with special offers,                                                                                                                                          14
# brand name paperwhite,,,\r\nbrand name paperwhite,,,                                                                                                                                                                              9
# brand name dx leather cover, black (fits 9.7 display, latest and 2nd generation brand name dxs),,                                                                                                                                 9
# retail brand echo and xyz brand tv power adapter,,,\r\nretail brand echo and xyz brand tv power adapter,,,                                                                                                                        7
# electonics brand home\n                                                                                                                                                                                                           7
# brand name oasis e-reader with leather charging cover - black, 6 high-resolution display (300 ppi), wi-fi - includes special offers,,                                                                                             6
# retail brand xyz brand kids edition tablet, 7 display, wi-fi, 16 gb, blue kid-proof case - blue                                                                                                                                   6
# retail brand xyz brand hd 6 standing protective case(4th generation - 2014 release), cayenne red,,,\r\nretail brand xyz brand hd 6 standing protective case(4th generation - 2014 release), cayenne red,,,                        6
# xyz brand hd 8 tablet with alexa, 8 hd display, 16 gb, tangerine - with special offers,                                                                                                                                           6
# new retail brand brand name xyz brand hd 9w powerfast adapter charger + micro usb angle cable,,,\r\nnew retail brand brand name xyz brand hd 9w powerfast adapter charger + micro usb angle cable,,,                              6
# retail brand - xyz brand 16gb (5th gen, 2015 release) - black,,,\r\nretail brand - xyz brand 16gb (5th gen, 2015 release) - black,,,                                                                                              4
# retail brand brand name xyz brand 5ft usb to micro-usb cable (works with most micro-usb tablets),,,\r\nretail brand brand name xyz brand 5ft usb to micro-usb cable (works with most micro-usb tablets),,,                        4
# certified refurbished electronics brand tv with alexa voice remote,,,\r\ncertified refurbished electronics brand tv with alexa voice remote,,,                                                                                    4
# electonics brand home                                                                                                                                                                                                             4
# retail brand brand name touch leather case (4th generation - 2011 release), olive green,,,\r\nretail brand brand name touch leather case (4th generation - 2011 release), olive green,,,                                          3
# retail brand brand name xyz brand hd (3rd generation) 8gb,,,\r\nretail brand brand name xyz brand hd (3rd generation) 8gb,,,                                                                                                      2
# certified refurbished electronics brand tv (previous generation - 1st),,,\r\ncertified refurbished electronics brand tv (previous generation - 1st),,,                                                                            2
# coconut water red tea 16.5 oz (pack of 12),,,\r\nelectronics brand tv,,,                                                                                                                                                          1
# brand name keyboard,,,\r\nbrand name keyboard,,,                                                                                                                                                                                  1
# retail brand brand name lighted leather cover,,,\r\nretail brand brand name lighted leather cover,,,                                                                                                                              1
# retail brand xyz brand tv,,,\nretail brand xyz brand tv,,,                                                                                                                                                                        1
# retail brand tap portable bluetooth and wi-fi speaker - black,,,\nretail brand tap portable bluetooth and wi-fi speaker - black,,,                                                                                                1
# retail brand brand name lighted leather cover,,,\nretail brand brand name lighted leather cover,,,                                                                                                                                1
# retail brand brand name lighted leather cover,,,\r\nbrand name keyboard,,,                                                                                                                                                        1
# retail brand xyz brand hd 6 standing protective case(4th generation - 2014 release), cayenne red,,,\r\nretail brand 5w usb official oem charger and power adapter for xyz brand tablets and brand name ereaders,,,                1
# retail brand xyz brand tv,,,\r\nbrand name dx leather cover, black (fits 9.7 display, latest and 2nd generation brand name dxs)",,                                                                                                1
# certified refurbished electronics brand tv (previous generation - 1st),,,\ncertified refurbished electronics brand tv (previous generation - 1st),,,                                                                              1
# 9w powerfast official oem usb charger and power adapter for xyz brand tablets and brand name ereaders,,,\n9w powerfast official oem usb charger and power adapter for xyz brand tablets and brand name ereaders,,,                1
# retail brand xyz brand 9w powerfast official oem usb charger and power adapter for xyz brand tablets and brand name ereaders,,,                                                                                                   1
# electonics brand home\r\nxyz brand tablet, 7 display, wi-fi, 8 gb - includes special offers, tangerine"                                                                                                                           1
# retail brand 5w usb official oem charger and power adapter for xyz brand tablets and brand name ereaders,,,\nretail brand 5w usb official oem charger and power adapter for xyz brand tablets and brand name ereaders,,,          1
# retail brand - xyz brand 16gb (5th gen, 2015 release) - black,,,\nretail brand - xyz brand 16gb (5th gen, 2015 release) - black,,,                                                                                                1
# retail brand xyz brand hd 8 8in tablet 16gb black b018szt3bk 6th gen (2016) android,,,\nretail brand xyz brand hd 8 8in tablet 16gb black b018szt3bk 6th gen (2016) android,,,                                                    1
# retail brand echo and xyz brand tv power adapter,,,\nretail brand echo and xyz brand tv power adapter,,,                                                                                                                          1
# retail brand - brand name voyage - 4gb - wi-fi + 3g - black,,,\nretail brand - brand name voyage - 4gb - wi-fi + 3g - black,,,                                                                                                    1
# certified refurbished electronics brand tv stick (previous generation - 1st),,,\r\nbrand name paperwhite,,,                                                                                                                       1
# certified refurbished electronics brand tv stick (previous generation - 1st),,,\r\ncertified refurbished electronics brand tv stick (previous generation - 1st),,,                                                                1
# retail brand - brand name voyage - 4gb - wi-fi + 3g - black,,,\r\nxyz brand hd 8 tablet with alexa, 8 hd display, 16 gb, tangerine - with special offers",                                                                        1
# standing protective case for xyz brand hd 6 (4th generation) - black,,,\nstanding protective case for xyz brand hd 6 (4th generation) - black,,,                                                                                  1
# new retail brand brand name xyz brand hd 9w powerfast adapter charger + micro usb angle cable,,,\r\n                                                                                                                              1
# Name: count, dtype: int64

# %% [markdown]
# __Using regular expressions (regex) to set a format for extracting common entities from different products.__

# %%
import re

# function for extracting product features
def extract_product_entities(text):
    entities = []
    
    # Regular expressions for specific entities
    display_regex = r"(\d+in|\d+\.\d+in|\d+ (?:in|inch|display))"  # Display size
    numbers_regex = r"(\d+|\d+\.\d+|\d+ (?:w|ft|th|release))" # Power/wattage
    memory_regex = r"(\d+ gb|\d+gb)"  # Memory
    # color_regex = r"(?i)(?:(?:black|white|red|blue|yellow|green|cyan|tangerine|purple|violet))"  # Color
    device_regex = r"(?i)(?:(?:ipad|tablet|ebook-reader|ebook\s+reader|speaker|tv|charging\s+cover|leather\s+cover|protective\s+case|micro|usb|cable|usb\s+charger|power\s+adapter|echo|keyboard))"  # Device type (case-insensitive)
    other_regex = r"(?i)(?:\b(touchscreen|wi-fi|bluetooth|high-resolution|pagepress\s+sensors|home|portable|kid-proof|android|kids\s+edition||refurbished|generation|alexa)\b)"  # Other keywords
    
    # Extract entities using regex
    entities.extend(re.findall(display_regex, text))
    entities.extend(re.findall(numbers_regex, text))
    entities.extend(re.findall(memory_regex, text))
    # entities.extend(re.findall(color_regex, text))
    entities.extend(re.findall(device_regex, text))
    entities.extend(re.findall(other_regex, text))

    # Clean and lowercase entities
    entities = [e.lower() for e in entities if e]
    
    return entities

# %%
# function for extracting source entities
def extract_source_entities(text):
    entities = []
    
    source_regex = r"(?i)(?:(?:target|target\s+coco\s+t|target\s+digital\s+services\s+inc.|target\s+echo|target\s+xyz\s+brand|target\s+xyz\s+brand\s+tv))"
    entities.extend(re.findall(source_regex, text))

    # Clean and lowercase entities
    entities = [e.lower() for e in entities if e]
    
    return entities

# %%
# Extracting entitiles from 'product' and 'source' columns

df['product_entities'] = df['product'].apply(extract_product_entities)
df['source_entities'] = df['source'].apply(extract_source_entities)

# %%
print("Product Entities:\n", df['product_entities'], "\n ------------------------------------------------ \n")
print("Source Entities:\n", df['source_entities'], "\n ------------------------------------------------ \n")
# Out:
# Product Entities:
#  0        [10, 1, 8, 16, 16 gb, tablet, tablet, wi-fi]
# 1        [10, 1, 8, 16, 16 gb, tablet, tablet, wi-fi]
# 2        [10, 1, 8, 16, 16 gb, tablet, tablet, wi-fi]
# 3        [10, 1, 8, 16, 16 gb, tablet, tablet, wi-fi]
# 4        [10, 1, 8, 16, 16 gb, tablet, tablet, wi-fi]
#                              ...
# 27895    [9, 9, micro, usb, cable, micro, usb, cable]
# 27896    [9, 9, micro, usb, cable, micro, usb, cable]
# 27897    [9, 9, micro, usb, cable, micro, usb, cable]
# 27898    [9, 9, micro, usb, cable, micro, usb, cable]
# 27899                          [9, micro, usb, cable]
# Name: product_entities, Length: 27868, dtype: object
#  ------------------------------------------------
#
# Source Entities:
#  0        [target]
# 1        [target]
# 2        [target]
# 3        [target]
# 4        [target]
#            ...
# 27895    [target]
# 27896    [target]
# 27897    [target]
# 27898    [target]
# 27899    [target]
# Name: source_entities, Length: 27868, dtype: object
#  ------------------------------------------------

# %%
# Joining entities as strings

df['product_entities'] = df['product_entities'].apply(lambda x: ' '.join(x))
df['source_entities'] = df['source_entities'].apply(lambda x: ' '.join(x))

# %%
df.head()
# Out:
#                                              product  source
# 0  electronics brand product name tablet a 10.1 t...  target  \
# 1  electronics brand product name tablet a 10.1 t...  target
# 2  electronics brand product name tablet a 10.1 t...  target
# 3  electronics brand product name tablet a 10.1 t...  target
# 4  electronics brand product name tablet a 10.1 t...  target
#
#                                           categories
# 0  electronics,ipad & tablets,all tablets,xyz bra...  \
# 1  electronics,ipad & tablets,all tablets,xyz bra...
# 2  electronics,ipad & tablets,all tablets,xyz bra...
# 3  electronics,ipad & tablets,all tablets,xyz bra...
# 4  electronics,ipad & tablets,all tablets,xyz bra...
#
#                        date  doRecommend  rating
# 0  2021-01-13T00:00:00.000Z         True     5.0  \
# 1  2021-01-13T00:00:00.000Z         True     5.0
# 2  2021-01-13T00:00:00.000Z         True     5.0
# 3  2021-01-13T00:00:00.000Z         True     4.0
# 4  2021-01-12T00:00:00.000Z         True     5.0
#
#                                              reviews
# 0  this product so far has not disappointed. my c...  \
# 1  great for beginner or experienced person. boug...
# 2  inexpensive tablet for him to use and learn on...
# 3  i've had my xyz brand hd 8 two weeks now and i...
# 4  i bought this for my grand daughter when she c...
#
#                                      title
# 0                               brand name  \
# 1                                very fast
# 2  beginner tablet for our 9 year old son.
# 3                                  good!!!
# 4                fantastic tablet for kids
#
#                       product_entities source_entities
# 0  10 1 8 16 16 gb tablet tablet wi-fi          target
# 1  10 1 8 16 16 gb tablet tablet wi-fi          target
# 2  10 1 8 16 16 gb tablet tablet wi-fi          target
# 3  10 1 8 16 16 gb tablet tablet wi-fi          target
# 4  10 1 8 16 16 gb tablet tablet wi-fi          target

# %% [markdown]
# __Next, calculating sentiment scores for product reviews.__

# %%
# Function to perform sentiment analysis

sid = SentimentIntensityAnalyzer()

def get_sentiment(text):
    sentiment = sid.polarity_scores(text)
    return sentiment['compound']  # Using compound score as an overall sentiment indicator

# %%
# Convert columns to type str 
str_cols = ['product', 'source', 'reviews', 'title']

for col in str_cols:
    df[col] = df[col].astype(str)

# %% [markdown]
# __Reason for converting columns to type str:__
# __Vader Lexicon's SentimentIntensityAnalyzer() is meant for working with text data. The columns in our dataframe have__
# __alphanumeric data, i.e. words and numbers. The numbers are considered as type float() by default in this function.__
# __We need these numbers to be considered as part of the text by SentimentIntensityAnalyzer().__
#
# __That's precisely why we have to convert the columns, before calculating polarity scores.__

# %%
# Apply sentiment analysis to 'Review' and 'Title' columns
df['review_sentiment'] = df['reviews'].apply(get_sentiment)
df['title_sentiment'] = df['title'].apply(get_sentiment)

# %% [markdown]
# __Calculating sentiment scores for the 'title' column may not be beneficial since it has very few words, and might return '0' for most cases. Let's see..__

# %%
df.head()
# Out:
#                                              product  source
# 0  electronics brand product name tablet a 10.1 t...  target  \
# 1  electronics brand product name tablet a 10.1 t...  target
# 2  electronics brand product name tablet a 10.1 t...  target
# 3  electronics brand product name tablet a 10.1 t...  target
# 4  electronics brand product name tablet a 10.1 t...  target
#
#                                           categories
# 0  electronics,ipad & tablets,all tablets,xyz bra...  \
# 1  electronics,ipad & tablets,all tablets,xyz bra...
# 2  electronics,ipad & tablets,all tablets,xyz bra...
# 3  electronics,ipad & tablets,all tablets,xyz bra...
# 4  electronics,ipad & tablets,all tablets,xyz bra...
#
#                        date  doRecommend  rating
# 0  2021-01-13T00:00:00.000Z         True     5.0  \
# 1  2021-01-13T00:00:00.000Z         True     5.0
# 2  2021-01-13T00:00:00.000Z         True     5.0
# 3  2021-01-13T00:00:00.000Z         True     4.0
# 4  2021-01-12T00:00:00.000Z         True     5.0
#
#                                              reviews
# 0  this product so far has not disappointed. my c...  \
# 1  great for beginner or experienced person. boug...
# 2  inexpensive tablet for him to use and learn on...
# 3  i've had my xyz brand hd 8 two weeks now and i...
# 4  i bought this for my grand daughter when she c...
#
#                                      title
# 0                               brand name  \
# 1                                very fast
# 2  beginner tablet for our 9 year old son.
# 3                                  good!!!
# 4                fantastic tablet for kids
#
#                       product_entities source_entities  review_sentiment
# 0  10 1 8 16 16 gb tablet tablet wi-fi          target            0.9194  \
# 1  10 1 8 16 16 gb tablet tablet wi-fi          target            0.8934
# 2  10 1 8 16 16 gb tablet tablet wi-fi          target            0.4404
# 3  10 1 8 16 16 gb tablet tablet wi-fi          target            0.9903
# 4  10 1 8 16 16 gb tablet tablet wi-fi          target            0.7650
#
#    title_sentiment
# 0           0.0000
# 1           0.0000
# 2           0.0000
# 3           0.5826
# 4           0.5574

# %%
# # calculating the count of occurrences of '0' in 'title_sentiment'
print(df['title_sentiment'].value_counts().get(0.0000, 0))
# Out:
# 4371

# %% [markdown]
# __As theorized, about 6.5% of the 'title_sentiment' scores are zero. So, I'll be combining both 'review_sentiment' and 'title_sentiment' scores to create a single feature, with more weightage given to product reviews as they possess more information and returning more accurate scores.__

# %%
title_weight = 0.2
review_weight = 0.8

# Calculate weighted average sentiment score
df['combined_sentiment'] = (title_weight * df['title_sentiment'] + review_weight * df['review_sentiment']) / (title_weight + review_weight)

# %%
df.head(5)
# Out:
#                                              product  source
# 0  electronics brand product name tablet a 10.1 t...  target  \
# 1  electronics brand product name tablet a 10.1 t...  target
# 2  electronics brand product name tablet a 10.1 t...  target
# 3  electronics brand product name tablet a 10.1 t...  target
# 4  electronics brand product name tablet a 10.1 t...  target
#
#                                           categories
# 0  electronics,ipad & tablets,all tablets,xyz bra...  \
# 1  electronics,ipad & tablets,all tablets,xyz bra...
# 2  electronics,ipad & tablets,all tablets,xyz bra...
# 3  electronics,ipad & tablets,all tablets,xyz bra...
# 4  electronics,ipad & tablets,all tablets,xyz bra...
#
#                        date  doRecommend  rating
# 0  2021-01-13T00:00:00.000Z         True     5.0  \
# 1  2021-01-13T00:00:00.000Z         True     5.0
# 2  2021-01-13T00:00:00.000Z         True     5.0
# 3  2021-01-13T00:00:00.000Z         True     4.0
# 4  2021-01-12T00:00:00.000Z         True     5.0
#
#                                              reviews
# 0  this product so far has not disappointed. my c...  \
# 1  great for beginner or experienced person. boug...
# 2  inexpensive tablet for him to use and learn on...
# 3  i've had my xyz brand hd 8 two weeks now and i...
# 4  i bought this for my grand daughter when she c...
#
#                                      title
# 0                               brand name  \
# 1                                very fast
# 2  beginner tablet for our 9 year old son.
# 3                                  good!!!
# 4                fantastic tablet for kids
#
#                       product_entities source_entities  review_sentiment
# 0  10 1 8 16 16 gb tablet tablet wi-fi          target            0.9194  \
# 1  10 1 8 16 16 gb tablet tablet wi-fi          target            0.8934
# 2  10 1 8 16 16 gb tablet tablet wi-fi          target            0.4404
# 3  10 1 8 16 16 gb tablet tablet wi-fi          target            0.9903
# 4  10 1 8 16 16 gb tablet tablet wi-fi          target            0.7650
#
#    title_sentiment  combined_sentiment
# 0           0.0000             0.73552
# 1           0.0000             0.71472
# 2           0.0000             0.35232
# 3           0.5826             0.90876
# 4           0.5574             0.72348

# %% [markdown]
# __The main features for model building will be 'rating', 'product_entities' and 'combined_sentiment'.__

# %% [markdown]
# __Not using 'source_entities' since it only has a single value ("Target") which isn't useful for recommendation in this case.__

# %% [markdown]
# __As for categories, they could be used similarly to product entities for content-based filtering. However, product entities might provide a more granular representation of product features.__

# %% [markdown]
# # Content-Based Filtering

# %%
text_features = df['product_entities'] + ' ' + df['reviews'] + ' ' + df['title']
tfidf_vectorizer = TfidfVectorizer()
tfidf_matrix = tfidf_vectorizer.fit_transform(text_features)
content_cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

# %%
# Function to get recommendations based on content similarity
def content_filtering(product_name, cosine_sim, top_n=5):
    idx = df[df['product'] == product_name].index[0]
    
    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:top_n+1]
    product_indices = [i[0] for i in sim_scores]

    # Filter out the input product name from recommendations
    similar_products_content = df['product'].iloc[product_indices]
    similar_products_content = similar_products_content[similar_products_content != product_name]
    
    return similar_products_content.unique()[:top_n]

# %%
# Example usage
product_name = 'electronics brand product name tablet a 10.1 tablet, 8 hd display, wi-fi, 16 gb - includes special offers, magenta'
recommendations = content_filtering(product_name, content_cosine_sim)
print("Recommendations for", product_name, ": \n", recommendations.tolist())
# Out:
# Recommendations for electronics brand product name tablet a 10.1 tablet, 8 hd display, wi-fi, 16 gb - includes special offers, magenta :
#  ['xyz brand tablet, 7 display, wi-fi, 8 gb - includes special offers, magenta', 'xyz brand kids edition tablet, 7 display, wi-fi, 16 gb, green kid-proof case']

# %% [markdown]
# __The function returns 2 unique products, related to the product name given.__

# %% [markdown]
# # Collaborative Filtering

# %%
def collaborative_filtering(product_name, data, top_n=5):
    # Create a rating matrix
    rating_matrix = data.groupby('product')['rating'].apply(list).apply(pd.Series).fillna(0)
    
    # Extracting the combined sentiment scores for all products
    product_sentiments = data.set_index('product')['combined_sentiment']
    
    # Calculate cosine similarity between product ratings
    cosine_sim = cosine_similarity(rating_matrix, rating_matrix)
    
    # Get index of the input product
    product_index = rating_matrix.index.get_loc(product_name)
    
    # Get indices of the top similar products (excluding the input product itself)
    similar_product_indices = cosine_sim[product_index].argsort()[::-1][1:top_n+1]
    
    # Get names of the top similar products
    similar_products = rating_matrix.iloc[similar_product_indices].index.tolist()
    
    return similar_products

# %%
# Example usage
product_name = 'retail brand brand name paperwhite - ebook reader - 4 gb - 6 monochrome paperwhite - touchscreen - wi-fi - black,,,'
similar_products = collaborative_filtering(product_name, df)
print("Top similar products to", product_name, ":\n", similar_products)
# Out:
# Top similar products to retail brand brand name paperwhite - ebook reader - 4 gb - 6 monochrome paperwhite - touchscreen - wi-fi - black,,, :
#  ['electronics brand product name tablet a 10.1 tablet, 8 hd display, wi-fi, 16 gb - includes special offers, magenta', 'retail brand xyz brand tv,,,\r\nretail brand xyz brand tv,,,', 'electonics brand home\r\nelectonics brand home', 'xyz brand kids edition tablet, 7 display, wi-fi, 16 gb, green kid-proof case', '\nelectonics brand home']

# %% [markdown]
# __The function returns 5 unique products.__

# %% [markdown]
# # Hybrid model

# %%
def hybrid_recommendations(product_name, df, top_n=5):
    
    # Content-Based Filtering
    text_features = df['product_entities'] + ' ' + df['reviews'] + ' ' + df['title']
    tfidf_vectorizer = TfidfVectorizer()
    tfidf_matrix = tfidf_vectorizer.fit_transform(text_features)
    content_cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)
    content_recommendations = content_filtering(product_name, content_cosine_sim, top_n)
    
    # Collaborative Filtering
    collaborative_recommendations = collaborative_filtering(product_name, df, top_n)
    
    # Combine recommendations
    hybrid_recommendations = list(set(content_recommendations) | set(collaborative_recommendations))
    
    # Exclude the input product from recommendations
    hybrid_recommendations = [prod for prod in hybrid_recommendations if prod != product_name]
    
    return hybrid_recommendations[:top_n]

# %%
# Example usage
product_name = 'brand new electronics brand ipad16gb 7 ips display tablet wifi 16 gb blue,,,'
hybrid_recs = hybrid_recommendations(product_name, df)
print("Hybrid Recommendations for", product_name, ":\n", hybrid_recs)
# Out:
# Hybrid Recommendations for brand new electronics brand ipad16gb 7 ips display tablet wifi 16 gb blue,,, :
#  ['\nelectonics brand home', 'electronics brand product name tablet a 10.1 tablet, 8 hd display, wi-fi, 16 gb - includes special offers, magenta', 'xyz brand kids edition tablet, 7 display, wi-fi, 16 gb, green kid-proof case', 'electonics brand home\r\nelectonics brand home', 'brand name voyage e-reader, 6 high-resolution display (300 ppi) with adaptive built-in light, pagepress sensors, wi-fi - includes special offers,']

# %% [markdown]
# __Successfully recommended products using the hybrid approach - combining content-based and collaborative-based filtering.__
